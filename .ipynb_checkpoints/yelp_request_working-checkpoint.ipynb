# %%
import csv
import pandas as pd
import requests
#import json as js
import matplotlib.pyplot as plt
from config import ykey

api_url = 'https://api.yelp.com'
search_path = '/v3/businesses/search'
business_path = '/v3/businesses/'
term = 'dinner'
location = 'San Francisco, CA'
limit = 50

headers = {'Authorization': 'Bearer ' + ykey}
params = {'term': term, 'location': location, 'limit': limit}

str(headers) + ' ' + str(params)
# Out:
# "{'Authorization': 'Bearer tNVSPxTZuK97fliYWToZrZpCGASCD0HlyF7s554dF_IdGdO1vAenbda05dWc6zUrsvXPE25NpvVJw1ZhohHYp-4n68rsIzrDPQAwh0lceNXGdjprDYMTAvHM_oMvXnYx'} {'term': 'dinner', 'location': 'San Francisco, CA', 'limit': 50}"

# %%
url = api_url + search_path 
response = requests.get(url, headers=headers, params=params)
print(response.status_code)
# Out:
# 200

# %%
test = response.json()
# Out:
# {'businesses': [{'id': 'lXMdrPSUmA9HfoHosOvzbQ',
#    'alias': 'mamahuhu-san-francisco-2',
#    'name': 'Mamahuhu',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7W8x3y0VKosT4aPMm0KU2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamahuhu-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 21,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78267, 'longitude': -122.46493},
#    'transactions': [],
#    'location': {'address1': '517 Clement St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['517 Clement St', 'San Francisco, CA 94118']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3474.8711276619647},
#   {'id': '2XwCg7dsjc_5zddwC4VaFA',
#    'alias': 'oji-san-francisco',
#    'name': 'Oji',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mphYvNuvCDsz1V79p3eGfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/oji-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 79,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.786171, 'longitude': -122.429681},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1740 Buchanan St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1740 Buchanan St', 'San Francisco, CA 94115']},
#    'phone': '+14156587103',
#    'display_phone': '(415) 658-7103',
#    'distance': 2873.3284031636304},
#   {'id': 'mdVq5YJoRhbQl2DD9BPQHw',
#    'alias': 'mamo-san-francisco',
#    'name': 'MaMo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1HVt_hzkG44xVoIJhY1sAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamo-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 93,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'colombian', 'title': 'Colombian'},
#     {'alias': 'venezuelan', 'title': 'Venezuelan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80384, 'longitude': -122.43366},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '3659 Buchanan St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3659 Buchanan St', 'San Francisco, CA 94123']},
#    'phone': '+14156587150',
#    'display_phone': '(415) 658-7150',
#    'distance': 4780.057821233973},
#   {'id': 'KkAVX3Wb7E3lP5F_f_8pXg',
#    'alias': 'liholiho-yacht-club-san-francisco-2',
#    'name': 'Liholiho Yacht Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FK2X98w6z5naJyiQjsGTNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/liholiho-yacht-club-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2374,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78818, 'longitude': -122.41458},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '871 Sutter St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['871 Sutter St', 'San Francisco, CA 94109']},
#    'phone': '+14154405446',
#    'display_phone': '(415) 440-5446',
#    'distance': 3595.021955242772},
#   {'id': 'ZoZjbOYR-apY8XvommlNUA',
#    'alias': 'the-house-san-francisco',
#    'name': 'The House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UzrNIkdGTZ1-cXuQDsKUmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-house-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 4812,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.79851, 'longitude': -122.40706},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '1230 Grant Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1230 Grant Ave', 'San Francisco, CA 94133']},
#    'phone': '+14159868612',
#    'display_phone': '(415) 986-8612',
#    'distance': 4911.928931733509},
#   {'id': '4KfQnlcSu4bbTqnvGdGptw',
#    'alias': 'beretta-san-francisco',
#    'name': 'Beretta',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RsCeyBgtnXpmN9YTKEIvWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/beretta-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 3606,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.753829, 'longitude': -122.420681},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1199 Valencia St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1199 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156951199',
#    'display_phone': '(415) 695-1199',
#    'distance': 1591.3097447927287},
#   {'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'alias': 'fog-harbor-fish-house-san-francisco-2',
#    'name': 'Fog Harbor Fish House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Lv7tIRX3Bim9bKqtWifmNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fog-harbor-fish-house-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 5981,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.809041, 'longitude': -122.410233},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': 'Pier 39',
#     'address2': 'Ste A-202',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Pier 39', 'Ste A-202', 'San Francisco, CA 94133']},
#    'phone': '+14154212442',
#    'display_phone': '(415) 421-2442',
#    'distance': 5827.740044156521},
#   {'id': '9Z9EETl8fZIP4s9KOHr5kg',
#    'alias': 'um-ma-san-francisco-3',
#    'name': 'um.ma',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9ILbI4cYVyeuVnTi4kGzjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/um-ma-san-francisco-3?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 269,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7655, 'longitude': -122.46608},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1220 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1220 9th Ave', 'San Francisco, CA 94122']},
#    'phone': '+14155665777',
#    'display_phone': '(415) 566-5777',
#    'distance': 2664.4699746595206},
#   {'id': '1hMD7RQogPDWpE-p3LKjXA',
#    'alias': 'loló-san-francisco-4',
#    'name': 'Loló',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2167,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7573462, 'longitude': -122.4214034},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '974 Valencia St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['974 Valencia St', 'San Francisco, CA 94110']},
#    'phone': '+14156435656',
#    'display_phone': '(415) 643-5656',
#    'distance': 1380.24804973913},
#   {'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#    'alias': 'kitchen-story-san-francisco',
#    'name': 'Kitchen Story',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NFhzbxcz4No5Ny8_IHdPMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-story-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 3293,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7642352, 'longitude': -122.4306936},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '3499 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3499 16th St', 'San Francisco, CA 94114']},
#    'phone': '+14155254905',
#    'display_phone': '(415) 525-4905',
#    'distance': 625.1566435901884},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'alias': 'nopa-san-francisco',
#    'name': 'Nopa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Li0xXDEM78GMG1xCYgYYaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nopa-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 5052,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77483, 'longitude': -122.43746},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '560 Divisadero St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['560 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14158648643',
#    'display_phone': '(415) 864-8643',
#    'distance': 1559.1831881623302},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'alias': 'farmhouse-kitchen-thai-cuisine-san-francisco',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/woO06sua7uMQNBf0wnjf8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmhouse-kitchen-thai-cuisine-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2354,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76026094, 'longitude': -122.4112048},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '710 Florida St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['710 Florida St', 'San Francisco, CA 94110']},
#    'phone': '+14158142920',
#    'display_phone': '(415) 814-2920',
#    'distance': 2220.139249062676},
#   {'id': 'oINcZKqhmB_sS-pv2z9IeA',
#    'alias': 'wei-guo-house-san-francisco',
#    'name': 'Wei Guo House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GAkOF8GucB7A5we-b_WD_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wei-guo-house-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 18,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78104, 'longitude': -122.45985},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '3751 Geary Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3751 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14156681588',
#    'display_phone': '(415) 668-1588',
#    'distance': 3044.0962096709827},
#   {'id': 'sfqkkqFmmYGOT0PCbbD9ZQ',
#    'alias': 'pearl-6101-san-francisco-6',
#    'name': 'Pearl 6101',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Iy2vlDWe-Xa70zbbPdgZHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pearl-6101-san-francisco-6?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 222,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7838344, 'longitude': -122.4830463},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '6101 California St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6101 California St', 'San Francisco, CA 94121']},
#    'phone': '+14155929777',
#    'display_phone': '(415) 592-9777',
#    'distance': 4827.880111203369},
#   {'id': 'u1SfgyXufKvyFLbYZGGI_g',
#    'alias': 'che-fico-alimentari-san-francisco',
#    'name': 'Che Fico Alimentari',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2N7lH_R7eL_CZTOcfe8BQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/che-fico-alimentari-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 43,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.777467, 'longitude': -122.437936},
#    'transactions': [],
#    'location': {'address1': '834 Divisadero St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['834 Divisadero St', 'San Francisco, CA 94117']},
#    'phone': '+14154166980',
#    'display_phone': '(415) 416-6980',
#    'distance': 1846.8745363530402},
#   {'id': 'wxzx3duu1c0CcomzEOvfOQ',
#    'alias': 'the-front-porch-san-francisco',
#    'name': 'The Front Porch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0fmMVyqSKOMIqtkQksUTUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-front-porch-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2802,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7438, 'longitude': -122.422035},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '65 29th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['65 29th St', 'Ste A', 'San Francisco, CA 94110']},
#    'phone': '+14156957800',
#    'display_phone': '(415) 695-7800',
#    'distance': 2285.237602234066},
#   {'id': 'R1XWPW8n-AcdIEjU4KRZ0w',
#    'alias': 'barvale-san-francisco-4',
#    'name': 'barvale',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MgG77CTS-AOlSv6GLB-k-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barvale-san-francisco-4?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 334,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77574, 'longitude': -122.43829},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '661 Divisadero',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['661 Divisadero', 'San Francisco, CA 94117']},
#    'phone': '+14156545211',
#    'display_phone': '(415) 654-5211',
#    'distance': 1658.1789778902603},
#   {'id': 'i09UMzccKgyLwGYKDVP28w',
#    'alias': 'surisan-san-francisco',
#    'name': 'Surisan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CQjUMLXrjMLPOhRgDmGyGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/surisan-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 1853,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.80678, 'longitude': -122.41756},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '505 Beach St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94133',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['505 Beach St', 'San Francisco, CA 94133']},
#    'phone': '+14157718449',
#    'display_phone': '(415) 771-8449',
#    'distance': 5366.476620396218},
#   {'id': 'Gh3cLhqw1BqpFSN5BaemBg',
#    'alias': 'khamsa-san-francisco',
#    'name': 'Khamsa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bAfERDz9bPwVKgpEWTmSrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khamsa-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 211,
#    'categories': [{'alias': 'moroccan', 'title': 'Moroccan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76654, 'longitude': -122.41798},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1503 15th St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1503 15th St', 'San Francisco, CA 94103']},
#    'phone': '+16282331503',
#    'display_phone': '(628) 233-1503',
#    'distance': 1745.6989802259407},
#   {'id': 'gqVl3RprESEqkIPeJH0yOg',
#    'alias': 'zazie-san-francisco',
#    'name': 'Zazie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uuRvEU-cqPk-XlDbFAQjKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zazie-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 4369,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.765244, 'longitude': -122.4501138},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '941 Cole St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['941 Cole St', 'San Francisco, CA 94117']},
#    'phone': '+14155645332',
#    'display_phone': '(415) 564-5332',
#    'distance': 1294.8624343961546},
#   {'id': 'h5ohkmv-UQiJTKFzxSS6RQ',
#    'alias': 'noosh-san-francisco',
#    'name': 'Noosh',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/htZmQ5FmRZjYRujcb2T_WA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noosh-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 304,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7880771447147,
#     'longitude': -122.43393894285},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2001 Fillmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2001 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14152315985',
#    'display_phone': '(415) 231-5985',
#    'distance': 3030.055075171354},
#   {'id': '9BxwybESMtcZsXBO0K-axA',
#    'alias': 'berber-san-francisco-4',
#    'name': 'Berber',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nL6kgSzEbconRqr9XeAwlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/berber-san-francisco-4?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 220,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.79604, 'longitude': -122.42214},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1516 Broadway St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1516 Broadway St', 'San Francisco, CA 94109']},
#    'phone': '+14158007767',
#    'display_phone': '(415) 800-7767',
#    'distance': 4105.417392958053},
#   {'id': 'LjVlsV9tKGnv7e4Iyt9c5Q',
#    'alias': 'lark-san-francisco-2',
#    'name': 'Lark',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BiDUDWE3pDcZnRRvDk7ruA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lark-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 286,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.761243, 'longitude': -122.434248},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '4068 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4068 18th St', 'San Francisco, CA 94114']},
#    'phone': '+14154004623',
#    'display_phone': '(415) 400-4623',
#    'distance': 197.0605128915999},
#   {'id': 'o4x29HYKvEUf7Regrn-J9g',
#    'alias': 'troya-san-francisco-3',
#    'name': 'Troya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MLHVzACARD-Q6H9DbnTG7Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/troya-san-francisco-3?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 568,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7893743915288,
#     'longitude': -122.434076070785},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2125 Fillmore St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2125 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14155631000',
#    'display_phone': '(415) 563-1000',
#    'distance': 3173.1228071385012},
#   {'id': 'QZQGRJZ4bZCmNoXjs3z1XQ',
#    'alias': 'state-bird-provisions-san-francisco',
#    'name': 'State Bird Provisions',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ckOXfbcgSrAcHOG86zEKuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/state-bird-provisions-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2751,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78374, 'longitude': -122.433005},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '1529 Fillmore St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1529 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14157951272',
#    'display_phone': '(415) 795-1272',
#    'distance': 2557.7136800981866},
#   {'id': 'c0WpyZFR3EoEBKcoY2LZ3Q',
#    'alias': 'marlowe-san-francisco-2',
#    'name': 'Marlowe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4CskEpDaE2yCeF7VI5UYOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marlowe-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2713,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7783200510611,
#     'longitude': -122.396771288052},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '500 Brannan St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['500 Brannan St', 'San Francisco, CA 94107']},
#    'phone': '+14157771413',
#    'display_phone': '(415) 777-1413',
#    'distance': 3989.2680242711845},
#   {'id': '_hOVIgjVRl_HzvLaa65KJg',
#    'alias': 'the-snug-san-francisco',
#    'name': 'The Snug',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/a-wxpvrLKUQWAvpWp9BFFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-snug-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 188,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.79094, 'longitude': -122.43443},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2301 Fillmore St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2301 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14155625092',
#    'display_phone': '(415) 562-5092',
#    'distance': 3342.887795851584},
#   {'id': 'DLjqwgeEd4BxZT7qJKvWUw',
#    'alias': 'the-pawn-shop-san-francisco',
#    'name': 'The Pawn Shop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X0jMCkLRLsjz6Hw5lmEPmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pawn-shop-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 220,
#    'categories': [{'alias': 'speakeasies', 'title': 'Speakeasies'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78106, 'longitude': -122.40834},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '993 Mission St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['993 Mission St', 'San Francisco, CA 94103']},
#    'phone': '+14158748041',
#    'display_phone': '(415) 874-8041',
#    'distance': 3327.604471930507},
#   {'id': 'J7_-faNq_Ag9qTOlDn81Pw',
#    'alias': 'starbelly-san-francisco',
#    'name': 'Starbelly',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IQcRlC75Lea8bqgHpJ8Usg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/starbelly-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 1825,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7640744, 'longitude': -122.4325634},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '3583 16th St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3583 16th St', 'San Francisco, CA 94114']},
#    'phone': '+14152527500',
#    'display_phone': '(415) 252-7500',
#    'distance': 491.1178550023795},
#   {'id': 'd11DpeZN_2CBkaKGkEsKsw',
#    'alias': 'hom-korean-kitchen-san-francisco',
#    'name': 'HoM Korean Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5RLBTRknzbXhldhpvIUqVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hom-korean-kitchen-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 49,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78095, 'longitude': -122.41453},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '154 McAllister St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['154 McAllister St', 'San Francisco, CA 94102']},
#    'phone': '+14157958777',
#    'display_phone': '(415) 795-8777',
#    'distance': 2938.2951394917304},
#   {'id': '5pG5Rqy7sDx3rmV0CggrPw',
#    'alias': 'sf-honey-pig-korean-bbq-san-francisco-2',
#    'name': 'SF Honey Pig Korean BBQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rdjM9LxpX8a5JOxuX5vALA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sf-honey-pig-korean-bbq-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 40,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.78069, 'longitude': -122.46462},
#    'transactions': [],
#    'location': {'address1': '4217 Geary Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4217 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14157026565',
#    'display_phone': '(415) 702-6565',
#    'distance': 3315.852946790471},
#   {'id': 'E2Ri3Uudb3ogKfWBJIIhRw',
#    'alias': 'lokma-san-francisco',
#    'name': 'Lokma',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KbrbFMe9gT3dK6vRCUCwyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lokma-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 264,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78215, 'longitude': -122.47867},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1801 Clement St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94121',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1801 Clement St', 'San Francisco, CA 94121']},
#    'phone': '+14157026219',
#    'display_phone': '(415) 702-6219',
#    'distance': 4402.2665821297205},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'alias': 'marufuku-ramen-sf-san-francisco',
#    'name': 'Marufuku Ramen SF',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2lUFO5HWD7_RLDWlT5Nvuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marufuku-ramen-sf-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 2862,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.785155, 'longitude': -122.432075},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1581 Webster St',
#     'address2': 'Ste 235',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1581 Webster St',
#      'Ste 235',
#      'San Francisco, CA 94115']},
#    'phone': '+14158729786',
#    'display_phone': '(415) 872-9786',
#    'distance': 2724.336436836609},
#   {'id': 'VjXSJdgy7wnlbMqwRWEgqQ',
#    'alias': 'golden-crab-house-san-francisco',
#    'name': 'Golden Crab House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FrNEBH42jaUXL9_IXuGdmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-crab-house-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 206,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76368, 'longitude': -122.47777},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '1830 Irving St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94122',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1830 Irving St', 'San Francisco, CA 94122']},
#    'phone': '+14157026685',
#    'display_phone': '(415) 702-6685',
#    'distance': 3648.3712766969606},
#   {'id': 'r7RwvYMwxDuK3u26fHbYDA',
#    'alias': 'limón-rotisserie-san-francisco-3',
#    'name': 'Limón Rotisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 3176,
#    'categories': [{'alias': 'peruvian', 'title': 'Peruvian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7570514, 'longitude': -122.416461},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1001 S Van Ness Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1001 S Van Ness Ave', 'San Francisco, CA 94110']},
#    'phone': '+14158212134',
#    'display_phone': '(415) 821-2134',
#    'distance': 1808.3298970637697},
#   {'id': 'DL-2iaugPoULjvZ6pyNRAQ',
#    'alias': 'causwells-san-francisco-5',
#    'name': 'Causwells',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TVoM-20ZGYrdFou2SqcuiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/causwells-san-francisco-5?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 743,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.8001342713833,
#     'longitude': -122.441983893514},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2346 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2346 Chestnut St', 'San Francisco, CA 94123']},
#    'phone': '+14154476081',
#    'display_phone': '(415) 447-6081',
#    'distance': 4402.702661060376},
#   {'id': '2nXYpojLdnIWkFW-Xe7B2A',
#    'alias': 'padrecito-san-francisco',
#    'name': 'Padrecito',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BkdlyO05_0w0fhA-gkq78A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padrecito-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 918,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7656775, 'longitude': -122.4500746},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '901 Cole St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['901 Cole St', 'San Francisco, CA 94117']},
#    'phone': '+14157425505',
#    'display_phone': '(415) 742-5505',
#    'distance': 1310.453997730548},
#   {'id': 'ZSzXw0NgJTyOzcHwKY5eMA',
#    'alias': 'blind-butcher-san-francisco-2',
#    'name': 'Blind Butcher',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pwZNOzKXlfs2Y74HHVDkUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blind-butcher-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 98,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.76116, 'longitude': -122.43414},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4058 18th St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94114',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4058 18th St', 'San Francisco, CA 94114']},
#    'phone': '+14155292478',
#    'display_phone': '(415) 529-2478',
#    'distance': 208.376792182},
#   {'id': 'XhJ6ZYagcWNHpJ1H1KvNlQ',
#    'alias': 'a-mano-san-francisco-2',
#    'name': 'a Mano',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ezG_zJwov2QNZwyK14EkwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-mano-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 865,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.776963880538,
#     'longitude': -122.423868469312},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '450 Hayes St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['450 Hayes St', 'San Francisco, CA 94102']},
#    'phone': '+14155067401',
#    'display_phone': '(415) 506-7401',
#    'distance': 2100.777699621916},
#   {'id': 'ZN7x2duyVesVVzlhWJNamQ',
#    'alias': 'skool-san-francisco',
#    'name': 'Skool',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/47i057bRXAm_sIvA2obD5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/skool-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 1754,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7685096967036,
#     'longitude': -122.402136325836},
#    'transactions': ['pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1725 Alameda St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1725 Alameda St', 'San Francisco, CA 94103']},
#    'phone': '+14152558800',
#    'display_phone': '(415) 255-8800',
#    'distance': 3132.4940753864485},
#   {'id': 'DGyoVB9PdI9_jw0CNi_OPg',
#    'alias': 'suppenküche-san-francisco-2',
#    'name': 'Suppenküche',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HAumhGEjTcqstgie00Fjag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suppenk%C3%BCche-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 3119,
#    'categories': [{'alias': 'german', 'title': 'German'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7762603759766,
#     'longitude': -122.426391601562},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '525 Laguna St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94102',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['525 Laguna St', 'San Francisco, CA 94102']},
#    'phone': '+14152529289',
#    'display_phone': '(415) 252-9289',
#    'distance': 1919.7883063813613},
#   {'id': '5PGFsnFhDlpYVDI3TRNH6w',
#    'alias': 'dancing-yak-san-francisco-9',
#    'name': 'Dancing Yak',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dMq56bG4r9cUFMs65_uG0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dancing-yak-san-francisco-9?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 414,
#    'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.76852, 'longitude': -122.42259},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '280 Valencia St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['280 Valencia St', 'San Francisco, CA 94103']},
#    'phone': '+14155254857',
#    'display_phone': '(415) 525-4857',
#    'distance': 1486.4246862272382},
#   {'id': 'r2jiJk3yivcLkWSSYELGcA',
#    'alias': 'tataki-san-francisco',
#    'name': 'Tataki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fc3n53gUq5lZ_gD1VjUJ8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tataki-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 1278,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7878390504557,
#     'longitude': -122.441227674274},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '2827 California St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2827 California St', 'San Francisco, CA 94115']},
#    'phone': '+14159311182',
#    'display_phone': '(415) 931-1182',
#    'distance': 3024.874051233535},
#   {'id': '_EncdQezAzcShATMFXL0dA',
#    'alias': 'tropisueno-san-francisco-8',
#    'name': 'Tropisueno',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hUZgDmue1VRfvIXai6I0wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tropisueno-san-francisco-8?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 4421,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7853008468227,
#     'longitude': -122.403918653727},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '75 Yerba Buena Ln',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['75 Yerba Buena Ln', 'San Francisco, CA 94103']},
#    'phone': '+14152430299',
#    'display_phone': '(415) 243-0299',
#    'distance': 3941.5902762189608},
#   {'id': 'zGYVSB7l73iv3Ue-48q63A',
#    'alias': 'osteria-bella-san-francisco-2',
#    'name': 'Osteria Bella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FKp7GNDf-9os_zR4Is1zqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osteria-bella-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 103,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'vermouthbars', 'title': 'Vermouth Bars'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.78148, 'longitude': -122.46085},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '3848 Geary Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94118',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3848 Geary Blvd', 'San Francisco, CA 94118']},
#    'phone': '+14152210305',
#    'display_phone': '(415) 221-0305',
#    'distance': 3131.0997776794316},
#   {'id': 'PiY8Ks8KWlIcAvqNdMjvBA',
#    'alias': 'izakaya-kou-san-francisco-2',
#    'name': 'Izakaya KOU',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/a_VbSN_CoGYRiHCECSGpeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-kou-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 801,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.784139, 'longitude': -122.432649},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1560 Fillmore St',
#     'address2': None,
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94115',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1560 Fillmore St', 'San Francisco, CA 94115']},
#    'phone': '+14154419294',
#    'display_phone': '(415) 441-9294',
#    'distance': 2606.9566582458197},
#   {'id': 'TV6jm9XQ4TA2DWD9n2vBbw',
#    'alias': 'maven-san-francisco',
#    'name': 'Maven',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r8KbGAaDBi4Hj45Tfm7wPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maven-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 688,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.7720561411384,
#     'longitude': -122.431929123925},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '598 Haight St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['598 Haight St', 'San Francisco, CA 94117']},
#    'phone': '+14158297982',
#    'display_phone': '(415) 829-7982',
#    'distance': 1302.5896192013001},
#   {'id': 'QHEvjDuIQc7ebYpEaB_TjA',
#    'alias': 'rooftop-25-san-francisco-2',
#    'name': 'Rooftop 25',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wTnsap_XlLTsqglyfH-eDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rooftop-25-san-francisco-2?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 152,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 37.77851, 'longitude': -122.39432},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '25 Lusk St',
#     'address2': '',
#     'address3': None,
#     'city': 'San Francisco',
#     'zip_code': '94107',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['25 Lusk St', 'San Francisco, CA 94107']},
#    'phone': '+14154955875',
#    'display_phone': '(415) 495-5875',
#    'distance': 4186.859438105963},
#   {'id': 'bH8FgQYhxkj5qQ4wL7vPFA',
#    'alias': 'tuba-authentic-turkish-restaurant-san-francisco',
#    'name': 'Tuba Authentic Turkish Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qRFJ_Tb2sQsMNSTxSa819w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuba-authentic-turkish-restaurant-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 1021,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.754898, 'longitude': -122.422906},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1007 Guerrero St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94110',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1007 Guerrero St', 'San Francisco, CA 94110']},
#    'phone': '+14158268822',
#    'display_phone': '(415) 826-8822',
#    'distance': 1361.904040975519},
#   {'id': 'ZTocvrJNFdVRz3NUToXaVQ',
#    'alias': 'inovino-san-francisco',
#    'name': 'InoVino',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BdaPAQ1vu2WbiteNsh37Sg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/inovino-san-francisco?adjust_creative=bTV8F_bnMWhjazagcRNv9w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bTV8F_bnMWhjazagcRNv9w',
#    'review_count': 153,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 37.7658664, 'longitude': -122.4502686},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '108B Carl St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Francisco',
#     'zip_code': '94117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['108B Carl St', 'San Francisco, CA 94117']},
#    'phone': '+14156813770',
#    'display_phone': '(415) 681-3770',
#    'distance': 1334.614191438859}],
#  'total': 6000,
#  'region': {'center': {'longitude': -122.43644714355469,
#    'latitude': 37.76089938976322}}}

# %%
value = []
value.append(response[0]['businesses']['alias'])

value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cdc34fd4d09e> in <module>
#       1 value = []
# ----> 2 value.append(response[0]['businesses']['alias'])
#       3
#       4 value
#       5
#
# TypeError: 'Response' object is not subscriptable
