# %%
#%matplotlib notebook

# %%
import csv, os, requests, time, pandas as pd, matplotlib.pyplot as plt, numpy as np
from config import *

# %%
yelpapi_csv = os.path.join("yelpapidata.csv")
yelp_raw = pd.read_csv(yelpapi_csv)
yelp_raw.head()
# Out:
#            search_city search_cuisine                    y_id  \
# 0  Montgomery, Alabama       American  BhPj9fLZph1TcofvuTZT1w
# 1  Montgomery, Alabama       American  4uVYV49MDmm3tunRg6hnew
# 2  Montgomery, Alabama       American  s2uIZz572lvzeeaT40xm5g
# 3  Montgomery, Alabama       American  TmPADgXsze5_gfTZPZ24vQ
# 4  Montgomery, Alabama       American  u-pZS8ZvEm8QwJIMrf1Wbw
#
#                           name  \
# 0              Urban Cookhouse
# 1              Stockyard Grill
# 2  Plantation House and Garden
# 3             Southern Comfort
# 4          Common Bond Brewers
#
#                                            image_url  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/XY8xxa...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/gfK2DK...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E4UqZ2...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/3WRpNu...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/xNl0HP...
#
#                                                  url  closed  review_count  \
# 0  https://www.yelp.com/biz/urban-cookhouse-montg...   False           142
# 1  https://www.yelp.com/biz/stockyard-grill-montg...   False            51
# 2  https://www.yelp.com/biz/plantation-house-and-...   False            14
# 3  https://www.yelp.com/biz/southern-comfort-hope...   False           193
# 4  https://www.yelp.com/biz/common-bond-brewers-m...   False            16
#
#    rating price        lat       long                 add1        city state  \
# 0     4.5     $  32.360651 -86.157520  7712 Eastchase Pkwy  Montgomery    AL
# 1     4.5     $  32.317361 -86.350667      4500 Mobile Hwy  Montgomery    AL
# 2     4.0    $$  32.479502 -86.369687    3240 Grandview Rd   Millbrook    AL
# 3     4.5    $$  32.269824 -86.363997        210 Wasden Rd   Hope Hull    AL
# 4     5.0     $  32.377410 -86.313590          424 Bibb St  Montgomery    AL
#
#   zip_code country         disp_ph
# 0    36117      US  (334) 239-7801
# 1    36108      US  (334) 288-2575
# 2    36054      US  (334) 285-1466
# 3    36043      US  (334) 280-0012
# 4    36104      US  (334) 676-2287

# %%
yelp_raw.describe()
# Out:
#        review_count        rating           lat          long
# count  27851.000000  27851.000000  27850.000000  27850.000000
# mean     177.127679      3.967398     38.425217    -92.894844
# std      292.762941      0.604082      5.160674     18.784798
# min        1.000000      1.000000     21.262370   -158.105524
# 25%       30.000000      3.500000     35.493787   -104.917115
# 50%       88.000000      4.000000     39.667450    -89.220339
# 75%      212.000000      4.500000     41.822154    -78.533204
# max     9460.000000      5.000000     58.398782    157.941630

# %%
yelp_format_rd1 = yelp_raw.copy()
#yelp_format_rd1["review_count"] = yelp_format_rd1.loc[:, "review_count"].astype(float)
#yelp_format_rd1["rating"] = yelp_format_rd1.loc[:, "rating"].astype(float)
yelp_format_rd1['price_attribute'] = yelp_format_rd1['price'].replace(
    {'$': '1.Affordable', '$$': '2.Moderate', '$$$': '3.Expensive'})
yelp_format_rd1.head()
# Out:
#            search_city search_cuisine                    y_id  \
# 0  Montgomery, Alabama       American  BhPj9fLZph1TcofvuTZT1w
# 1  Montgomery, Alabama       American  4uVYV49MDmm3tunRg6hnew
# 2  Montgomery, Alabama       American  s2uIZz572lvzeeaT40xm5g
# 3  Montgomery, Alabama       American  TmPADgXsze5_gfTZPZ24vQ
# 4  Montgomery, Alabama       American  u-pZS8ZvEm8QwJIMrf1Wbw
#
#                           name  \
# 0              Urban Cookhouse
# 1              Stockyard Grill
# 2  Plantation House and Garden
# 3             Southern Comfort
# 4          Common Bond Brewers
#
#                                            image_url  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/XY8xxa...
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/gfK2DK...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E4UqZ2...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/3WRpNu...
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/xNl0HP...
#
#                                                  url  closed  review_count  \
# 0  https://www.yelp.com/biz/urban-cookhouse-montg...   False           142
# 1  https://www.yelp.com/biz/stockyard-grill-montg...   False            51
# 2  https://www.yelp.com/biz/plantation-house-and-...   False            14
# 3  https://www.yelp.com/biz/southern-comfort-hope...   False           193
# 4  https://www.yelp.com/biz/common-bond-brewers-m...   False            16
#
#    rating price        lat       long                 add1        city state  \
# 0     4.5     $  32.360651 -86.157520  7712 Eastchase Pkwy  Montgomery    AL
# 1     4.5     $  32.317361 -86.350667      4500 Mobile Hwy  Montgomery    AL
# 2     4.0    $$  32.479502 -86.369687    3240 Grandview Rd   Millbrook    AL
# 3     4.5    $$  32.269824 -86.363997        210 Wasden Rd   Hope Hull    AL
# 4     5.0     $  32.377410 -86.313590          424 Bibb St  Montgomery    AL
#
#   zip_code country         disp_ph price_attribute
# 0    36117      US  (334) 239-7801    1.Affordable
# 1    36108      US  (334) 288-2575    1.Affordable
# 2    36054      US  (334) 285-1466      2.Moderate
# 3    36043      US  (334) 280-0012      2.Moderate
# 4    36104      US  (334) 676-2287    1.Affordable

# %%
yelp_format_rd1.columns
# Out:
# Index(['search_city', 'search_cuisine', 'y_id', 'name', 'image_url', 'url',
#        'closed', 'review_count', 'rating', 'price', 'lat', 'long', 'add1',
#        'city', 'state', 'zip_code', 'country', 'disp_ph', 'price_attribute'],
#       dtype='object')

# %%
yelp_format_rd1.count()
# Out:
# search_city        27851
# search_cuisine     27851
# y_id               27851
# name               27851
# image_url          27532
# url                27851
# closed             27851
# review_count       27851
# rating             27851
# price              23729
# lat                27850
# long               27850
# add1               27496
# city               27851
# state              27851
# zip_code           27822
# country            27851
# disp_ph            27251
# price_attribute    23729
# dtype: int64

# %%
yelp_format_rd1.dtypes
# Out:
# search_city         object
# search_cuisine      object
# y_id                object
# name                object
# image_url           object
# url                 object
# closed                bool
# review_count         int64
# rating             float64
# price               object
# lat                float64
# long               float64
# add1                object
# city                object
# state               object
# zip_code            object
# country             object
# disp_ph             object
# price_attribute     object
# dtype: object

# %%
yelp_gb_cities = yelp_format_rd1.groupby(['search_city'])
yelp_gb_cities.sum().head()
# Out:
#                      closed  review_count  rating           lat          long
# search_city
# Albany, New York      False         61218  2506.0  27242.467834 -47077.268325
# Annapolis, Maryland   False         96385  1912.0  19436.953223 -38130.413818
# Atlanta, Georgia      False        287240  3898.0  32554.059412 -81150.804242
# Augusta, Maine        False         15429  1021.0  11696.821371 -18341.337151
# Austin, Texas         False        299061  3792.0  27810.980645 -89635.319822

# %%
yelp_gb_cuisines = yelp_format_rd1.groupby(['search_cuisine'])
yelp_gb_cuisines.sum().head()
# Out:
#                 closed  review_count  rating           lat           long
# search_cuisine
# American           0.0        658067  9574.5  93656.108174 -222832.643590
# Cajun              0.0        364110  5698.0  56090.625394 -139019.652525
# Caribbean          0.0         89119  3081.5  29446.371743  -67662.051855
# Chinese            0.0        215002  7071.0  73497.901854 -178476.610595
# French             0.0        251601  4517.5  43102.898712 -105380.021478

# %%
yelp_gb_price = yelp_format_rd1.groupby(['price'])
yelp_gb_price.sum().head()
# Out:
#        closed  review_count   rating            lat          long
# price
# $         2.0        736368  26193.5  257384.932815 -6.172942e+05
# $$        0.0       3755842  62684.0  611843.526283 -1.491098e+06
# $$$       0.0        334326   4027.0   38330.086618 -9.183231e+04
# $$$$      0.0         30459    460.0    3951.409992 -1.070779e+04

# %%
yelp_gb_citiescount = yelp_format_rd1.groupby(['search_city'])
yelp_gb_citiescount.count().head()
# Out:
#                      search_cuisine  y_id  name  image_url  url  closed  \
# search_city
# Albany, New York                638   638   638        628  638     638
# Annapolis, Maryland             498   498   498        496  498     498
# Atlanta, Georgia                962   962   962        960  962     962
# Augusta, Maine                  264   264   264        253  264     264
# Austin, Texas                   917   917   917        915  917     917
#
#                      review_count  rating  price  lat  long  add1  city  \
# search_city
# Albany, New York              638     638    531  638   638   632   638
# Annapolis, Maryland           498     498    437  498   498   490   498
# Atlanta, Georgia              962     962    851  962   962   960   962
# Augusta, Maine                264     264    210  264   264   264   264
# Austin, Texas                 917     917    768  917   917   910   917
#
#                      state  zip_code  country  disp_ph  price_attribute
# search_city
# Albany, New York       638       638      638      622              531
# Annapolis, Maryland    498       498      498      493              437
# Atlanta, Georgia       962       962      962      947              851
# Augusta, Maine         264       264      264      261              210
# Austin, Texas          917       916      917      890              768

# %%
yelp_gb_cuisinescount = yelp_format_rd1.groupby(['search_cuisine'])
yelp_gb_cuisinescount.count().head()
# Out:
#                 search_city  y_id  name  image_url   url  closed  \
# search_cuisine
# American               2396  2396  2396       2368  2396    2396
# Cajun                  1491  1491  1491       1479  1491    1491
# Caribbean               764   764   764        738   764     764
# Chinese                1914  1914  1914       1887  1914    1914
# French                 1118  1118  1118       1111  1118    1118
#
#                 review_count  rating  price   lat  long  add1  city  state  \
# search_cuisine
# American                2396    2396   2039  2396  2396  2392  2396   2396
# Cajun                   1491    1491   1281  1491  1491  1470  1491   1491
# Caribbean                764     764    532   764   764   724   764    764
# Chinese                 1914    1914   1716  1914  1914  1912  1914   1914
# French                  1118    1118   1018  1118  1118  1111  1118   1118
#
#                 zip_code  country  disp_ph  price_attribute
# search_cuisine
# American            2396     2396     2346             2039
# Cajun               1491     1491     1451             1281
# Caribbean            761      764      735              532
# Chinese             1913     1914     1883             1716
# French              1117     1118     1097             1018

# %%
yelp_gb_citiesavg = yelp_format_rd1.groupby(['search_city'])
yelp_gb_citiesavg.mean().head()
# Out:
#                      closed  review_count    rating        lat       long
# search_city
# Albany, New York        0.0     95.952978  3.927900  42.699793 -73.788822
# Annapolis, Maryland     0.0    193.544177  3.839357  39.030027 -76.567096
# Atlanta, Georgia        0.0    298.586279  4.051975  33.839979 -84.356345
# Augusta, Maine          0.0     58.443182  3.867424  44.306142 -69.474762
# Austin, Texas           0.0    326.129771  4.135224  30.328223 -97.748440

# %%
yelp_gb_cuisinesavg = yelp_format_rd1.groupby(['search_cuisine'])
yelp_gb_cuisinesavg.mean().head()
# Out:
#                 closed  review_count    rating        lat       long
# search_cuisine
# American           0.0    274.652337  3.996035  39.088526 -93.001938
# Cajun              0.0    244.205231  3.821596  37.619467 -93.239204
# Caribbean          0.0    116.647906  4.033377  38.542371 -88.562895
# Chinese            0.0    112.331243  3.694357  38.400158 -93.247968
# French             0.0    225.045617  4.040698  38.553577 -94.257622

# %%
yelp_gb2_citiesavg = yelp_format_rd1.groupby(['search_city','search_cuisine'])
yelp_gb2_citiesavg.mean().head()
# Out:
#                                  closed  review_count    rating        lat  \
# search_city      search_cuisine
# Albany, New York American           0.0    138.660000  4.090000  42.687656
#                  Cajun              0.0    134.363636  3.681818  42.712528
#                  Caribbean          0.0     21.583333  3.625000  42.700434
#                  Chinese            0.0     85.920000  3.570000  42.686607
#                  French             0.0     71.071429  3.964286  42.704651
#
#                                       long
# search_city      search_cuisine
# Albany, New York American       -73.781079
#                  Cajun          -73.783241
#                  Caribbean      -73.791653
#                  Chinese        -73.793954
#                  French         -73.786837

# %%
yelp_gb2_cuisinesavg = yelp_format_rd1.groupby(['search_cuisine','search_city'])
yelp_gb2_cuisinesavg.mean().head()
# Out:
#                                     closed  review_count  rating        lat  \
# search_cuisine search_city
# American       Albany, New York        0.0        138.66    4.09  42.687656
#                Annapolis, Maryland     0.0        281.00    3.99  38.976601
#                Atlanta, Georgia        0.0        708.70    4.20  33.799748
#                Augusta, Maine          0.0         47.28    4.00  44.354949
#                Austin, Texas           0.0        657.44    4.24  30.331474
#
#                                          long
# search_cuisine search_city
# American       Albany, New York    -73.781079
#                Annapolis, Maryland -76.507178
#                Atlanta, Georgia    -84.392725
#                Augusta, Maine      -69.726458
#                Austin, Texas       -97.749226

# %%
yelp_gb3_citiesavg = yelp_format_rd1.groupby(['search_city','search_cuisine'])
yelp_gb3_citiesavg.mean().head()
# Out:
#                                  closed  review_count    rating        lat  \
# search_city      search_cuisine
# Albany, New York American           0.0    138.660000  4.090000  42.687656
#                  Cajun              0.0    134.363636  3.681818  42.712528
#                  Caribbean          0.0     21.583333  3.625000  42.700434
#                  Chinese            0.0     85.920000  3.570000  42.686607
#                  French             0.0     71.071429  3.964286  42.704651
#
#                                       long
# search_city      search_cuisine
# Albany, New York American       -73.781079
#                  Cajun          -73.783241
#                  Caribbean      -73.791653
#                  Chinese        -73.793954
#                  French         -73.786837

# %%
yelp_gb3_cuisinesavg = yelp_format_rd1.groupby(['search_cuisine','search_city'])
yelp_gb3_cuisinesavg.mean().head()
# Out:
#                                     closed  review_count  rating        lat  \
# search_cuisine search_city
# American       Albany, New York        0.0        138.66    4.09  42.687656
#                Annapolis, Maryland     0.0        281.00    3.99  38.976601
#                Atlanta, Georgia        0.0        708.70    4.20  33.799748
#                Augusta, Maine          0.0         47.28    4.00  44.354949
#                Austin, Texas           0.0        657.44    4.24  30.331474
#
#                                          long
# search_cuisine search_city
# American       Albany, New York    -73.781079
#                Annapolis, Maryland -76.507178
#                Atlanta, Georgia    -84.392725
#                Augusta, Maine      -69.726458
#                Austin, Texas       -97.749226

# %%
#This is where we are going to start charting, I have provided some exmaples for you.

# %%
chartme1 = yelp_gb_cuisinesavg['rating'].mean()
cuisine_chart = chartme1.plot(kind='bar', title='mean rating by cuisine')
cuisine_chart.set_xlabel("cuisine group")
cuisine_chart.set_ylabel("yelp rating")

plt.show()
plt.tight_layout()

# %%
chartme2 = yelp_gb_citiesavg['rating'].mean()
cuisine_chart = chartme2.plot(kind='bar', title='mean rating by cuisine')
cuisine_chart.set_xlabel("yelp rating")
cuisine_chart.set_ylabel('our cities')

plt.show()
plt.tight_layout()

# %%
yelp_gb_c = yelp_gb_cuisinescount['search_cuisine']
yelp_gb_c.count()
# Out:
# search_cuisine
# American         2396
# Cajun            1491
# Caribbean         764
# Chinese          1914
# French           1118
# German            635
# Greek            1511
# Indian           1097
# Italian          2184
# Japanese         1737
# Korean           1486
# Lebanese          737
# Mediterranean    1289
# Mexican          2154
# Moroccan          399
# Soul             2001
# Spanish           977
# Thai             1771
# Turkish           772
# Vietnamese       1418
# Name: search_cuisine, dtype: int64

# %%
#variable

# %%
# Labels for the sections of our pie chart
food_type = yelp_format_rd1['search_cuisine'].unique()
food_type

variable = yelp_gb_cuisinescount['review_count'].sum()
variable
#cuisines_labels = yelp_format_rd1.groupby(['search_cuisine'])['review_count']
#cuisines_labels.head()

# The values of each section of the pie chart

#sizes = yelp_gb_cuisinescount['review_count']


# Tells matplotlib to seperate the "Python" section from the others
# Out:
# search_cuisine
# American         658067
# Cajun            364110
# Caribbean         89119
# Chinese          215002
# French           251601
# German           159661
# Greek            194577
# Indian           179828
# Italian          384256
# Japanese         333234
# Korean           259125
# Lebanese         153168
# Mediterranean    192793
# Mexican          346125
# Moroccan          80659
# Soul             195123
# Spanish          197642
# Thai             287673
# Turkish          150554
# Vietnamese       240866
# Name: review_count, dtype: int64

# %%
#actual pie chart
plt.pie(variable, labels=food_type, autopct="%1.1f%%", shadow=True, startangle= 0)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
food_data = yelp_format_rd1
food_data
#american_data = american_data.loc[american_data['American']]
#american_data.head()


#food_type2 = yelp_format_rd1['search_cuisine'].unique()
#food_type2

#variable = yelp_gb_cuisinescount['review_count'].sum()
#variable
# Out:
#                search_city search_cuisine                    y_id  \
# 0      Montgomery, Alabama       American  BhPj9fLZph1TcofvuTZT1w
# 1      Montgomery, Alabama       American  4uVYV49MDmm3tunRg6hnew
# 2      Montgomery, Alabama       American  s2uIZz572lvzeeaT40xm5g
# 3      Montgomery, Alabama       American  TmPADgXsze5_gfTZPZ24vQ
# 4      Montgomery, Alabama       American  u-pZS8ZvEm8QwJIMrf1Wbw
# ...                    ...            ...                     ...
# 27846    Cheyenne, Wyoming     Vietnamese  Xr_UtPKedDyleG_MSHvK-Q
# 27847    Cheyenne, Wyoming     Vietnamese  FS9UR3iy80xk4CityY-plw
# 27848    Cheyenne, Wyoming        Turkish  zzeqVazbBK6-drbYWWLR9A
# 27849    Cheyenne, Wyoming        Turkish  M2a9ML_cYBfjqwR9zxRYLg
# 27850    Cheyenne, Wyoming      Caribbean  l6UY1Z__os43azBV0D8c9A
#
#                                     name  \
# 0                        Urban Cookhouse
# 1                        Stockyard Grill
# 2            Plantation House and Garden
# 3                       Southern Comfort
# 4                    Common Bond Brewers
# ...                                  ...
# 27846                     Empire Express
# 27847                       College Cafe
# 27848  Petra Grill Mediterranean Cuisine
# 27849                        Tikka Grill
# 27850                              aDeli
#
#                                                image_url  \
# 0      https://s3-media1.fl.yelpcdn.com/bphoto/XY8xxa...
# 1      https://s3-media2.fl.yelpcdn.com/bphoto/gfK2DK...
# 2      https://s3-media3.fl.yelpcdn.com/bphoto/E4UqZ2...
# 3      https://s3-media2.fl.yelpcdn.com/bphoto/3WRpNu...
# 4      https://s3-media3.fl.yelpcdn.com/bphoto/xNl0HP...
# ...                                                  ...
# 27846  https://s3-media1.fl.yelpcdn.com/bphoto/00xiho...
# 27847  https://s3-media1.fl.yelpcdn.com/bphoto/0GxxFZ...
# 27848  https://s3-media2.fl.yelpcdn.com/bphoto/LtyGPN...
# 27849  https://s3-media2.fl.yelpcdn.com/bphoto/Xs6eqt...
# 27850  https://s3-media1.fl.yelpcdn.com/bphoto/osBbt5...
#
#                                                      url  closed  \
# 0      https://www.yelp.com/biz/urban-cookhouse-montg...   False
# 1      https://www.yelp.com/biz/stockyard-grill-montg...   False
# 2      https://www.yelp.com/biz/plantation-house-and-...   False
# 3      https://www.yelp.com/biz/southern-comfort-hope...   False
# 4      https://www.yelp.com/biz/common-bond-brewers-m...   False
# ...                                                  ...     ...
# 27846  https://www.yelp.com/biz/empire-express-laport...   False
# 27847  https://www.yelp.com/biz/college-cafe-fort-col...   False
# 27848  https://www.yelp.com/biz/petra-grill-mediterra...   False
# 27849  https://www.yelp.com/biz/tikka-grill-fort-coll...   False
# 27850  https://www.yelp.com/biz/adeli-cheyenne?adjust...   False
#
#        review_count  rating price        lat        long                 add1  \
# 0               142     4.5     $  32.360651  -86.157520  7712 Eastchase Pkwy
# 1                51     4.5     $  32.317361  -86.350667      4500 Mobile Hwy
# 2                14     4.0    $$  32.479502  -86.369687    3240 Grandview Rd
# 3               193     4.5    $$  32.269824  -86.363997        210 Wasden Rd
# 4                16     5.0     $  32.377410  -86.313590          424 Bibb St
# ...             ...     ...   ...        ...         ...                  ...
# 27846            32     2.5     $  40.657480 -105.160399     3300 W County Rd
# 27847            23     3.0     $  40.578299 -105.077356    647 S College Ave
# 27848           177     4.0    $$  40.574059 -105.100014  1335 W Elizabeth St
# 27849            50     4.5     $  40.574839 -105.099282  1240 W Elizabeth St
# 27850             1     5.0   NaN  41.176210 -104.827320  6101 Yellowstone Rd
#
#                city state zip_code country         disp_ph price_attribute
# 0        Montgomery    AL    36117      US  (334) 239-7801    1.Affordable
# 1        Montgomery    AL    36108      US  (334) 288-2575    1.Affordable
# 2         Millbrook    AL    36054      US  (334) 285-1466      2.Moderate
# 3         Hope Hull    AL    36043      US  (334) 280-0012      2.Moderate
# 4        Montgomery    AL    36104      US  (334) 676-2287    1.Affordable
# ...             ...   ...      ...     ...             ...             ...
# 27846       Laporte    CO    80535      US  (970) 493-2663    1.Affordable
# 27847  Fort Collins    CO    80524      US  (970) 221-2696    1.Affordable
# 27848  Fort Collins    CO    80521      US  (970) 568-8381      2.Moderate
# 27849  Fort Collins    CO    80521      US  (970) 698-6022    1.Affordable
# 27850      Cheyenne    WY    82009      US  (307) 286-8072             NaN
#
# [27851 rows x 19 columns]

# %%
only_american = food_data.loc[food_data['search_cuisine'] == 'American', :]
only_american

variable4 = only_city['review_count']['search_cuisine']
#.set_index("search_cuisine")
# Out:
#                search_city search_cuisine                    y_id  \
# 0      Montgomery, Alabama       American  BhPj9fLZph1TcofvuTZT1w
# 1      Montgomery, Alabama       American  4uVYV49MDmm3tunRg6hnew
# 2      Montgomery, Alabama       American  s2uIZz572lvzeeaT40xm5g
# 3      Montgomery, Alabama       American  TmPADgXsze5_gfTZPZ24vQ
# 4      Montgomery, Alabama       American  u-pZS8ZvEm8QwJIMrf1Wbw
# ...                    ...            ...                     ...
# 27592    Cheyenne, Wyoming       American  _ORLK0s2nLLaYXZb04B0dA
# 27593    Cheyenne, Wyoming       American  6C_JT7F1lb49tOEdhgbi3g
# 27594    Cheyenne, Wyoming       American  gOjySlPDE2KEnkwspnuk5w
# 27595    Cheyenne, Wyoming       American  e43SQ8a5M8BUvNPBlrIzAw
# 27596    Cheyenne, Wyoming       American  lKwlTEUIL7ScZiB1eYWEkw
#
#                               name  \
# 0                  Urban Cookhouse
# 1                  Stockyard Grill
# 2      Plantation House and Garden
# 3                 Southern Comfort
# 4              Common Bond Brewers
# ...                            ...
# 27592                      Wendy's
# 27593                      Wendy's
# 27594                         IHOP
# 27595               Sonic Drive-In
# 27596                  Burger King
#
#                                                image_url  \
# 0      https://s3-media1.fl.yelpcdn.com/bphoto/XY8xxa...
# 1      https://s3-media2.fl.yelpcdn.com/bphoto/gfK2DK...
# 2      https://s3-media3.fl.yelpcdn.com/bphoto/E4UqZ2...
# 3      https://s3-media2.fl.yelpcdn.com/bphoto/3WRpNu...
# 4      https://s3-media3.fl.yelpcdn.com/bphoto/xNl0HP...
# ...                                                  ...
# 27592  https://s3-media3.fl.yelpcdn.com/bphoto/H9Nb_I...
# 27593  https://s3-media3.fl.yelpcdn.com/bphoto/NipmWw...
# 27594  https://s3-media2.fl.yelpcdn.com/bphoto/jniaSB...
# 27595  https://s3-media3.fl.yelpcdn.com/bphoto/swn6qs...
# 27596  https://s3-media3.fl.yelpcdn.com/bphoto/YouV4f...
#
#                                                      url  closed  \
# 0      https://www.yelp.com/biz/urban-cookhouse-montg...   False
# 1      https://www.yelp.com/biz/stockyard-grill-montg...   False
# 2      https://www.yelp.com/biz/plantation-house-and-...   False
# 3      https://www.yelp.com/biz/southern-comfort-hope...   False
# 4      https://www.yelp.com/biz/common-bond-brewers-m...   False
# ...                                                  ...     ...
# 27592  https://www.yelp.com/biz/wendys-cheyenne-3?adj...   False
# 27593  https://www.yelp.com/biz/wendys-cheyenne-2?adj...   False
# 27594  https://www.yelp.com/biz/ihop-cheyenne-3?adjus...   False
# 27595  https://www.yelp.com/biz/sonic-drive-in-cheyen...   False
# 27596  https://www.yelp.com/biz/burger-king-cheyenne?...   False
#
#        review_count  rating price        lat        long  \
# 0               142     4.5     $  32.360651  -86.157520
# 1                51     4.5     $  32.317361  -86.350667
# 2                14     4.0    $$  32.479502  -86.369687
# 3               193     4.5    $$  32.269824  -86.363997
# 4                16     5.0     $  32.377410  -86.313590
# ...             ...     ...   ...        ...         ...
# 27592             9     2.5     $  41.160620 -104.796390
# 27593            12     2.5     $  41.097772 -104.848893
# 27594            39     1.5     $  41.160610 -104.793430
# 27595            30     2.0     $  41.116210 -104.802110
# 27596            12     1.5     $  41.118259 -104.803855
#
#                         add1        city state zip_code country  \
# 0        7712 Eastchase Pkwy  Montgomery    AL    36117      US
# 1            4500 Mobile Hwy  Montgomery    AL    36108      US
# 2          3240 Grandview Rd   Millbrook    AL    36054      US
# 3              210 Wasden Rd   Hope Hull    AL    36043      US
# 4                424 Bibb St  Montgomery    AL    36104      US
# ...                      ...         ...   ...      ...     ...
# 27592   1830 Dell Range Blvd    Cheyenne    WY    82009      US
# 27593     3305 W. College Dr    Cheyenne    WY    82007      US
# 27594   1938 Dell Range Blvd    Cheyenne    WY    82009      US
# 27595      125 S Greeley Hwy    Cheyenne    WY    82001      US
# 27596  205 North Greeley Hwy    Cheyenne    WY    82007      US
#
#               disp_ph price_attribute
# 0      (334) 239-7801    1.Affordable
# 1      (334) 288-2575    1.Affordable
# 2      (334) 285-1466      2.Moderate
# 3      (334) 280-0012      2.Moderate
# 4      (334) 676-2287    1.Affordable
# ...               ...             ...
# 27592  (307) 635-0392    1.Affordable
# 27593  (307) 638-2976    1.Affordable
# 27594  (307) 433-8488    1.Affordable
# 27595  (307) 432-0053    1.Affordable
# 27596  (307) 635-8277    1.Affordable
#
# [2396 rows x 19 columns]

# %%
variable2 = only_american.groupby(['search_city'])['search_cuisine']
variable2.head()
# Out:
# 0        American
# 1        American
# 2        American
# 3        American
# 4        American
#            ...
# 27552    American
# 27553    American
# 27554    American
# 27555    American
# 27556    American
# Name: search_cuisine, Length: 250, dtype: object

# %%
plt.pie(variable, labels=food_type, autopct="%1.1f%%", shadow=True, startangle= 0)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
only_city = food_data.loc[food_data['search_city'] == 'Montgomery, Alabama', :]
only_city
# Out:
#              search_city search_cuisine                    y_id  \
# 0    Montgomery, Alabama       American  BhPj9fLZph1TcofvuTZT1w
# 1    Montgomery, Alabama       American  4uVYV49MDmm3tunRg6hnew
# 2    Montgomery, Alabama       American  s2uIZz572lvzeeaT40xm5g
# 3    Montgomery, Alabama       American  TmPADgXsze5_gfTZPZ24vQ
# 4    Montgomery, Alabama       American  u-pZS8ZvEm8QwJIMrf1Wbw
# ..                   ...            ...                     ...
# 370  Montgomery, Alabama        Turkish  4qX7Gf-KPmrimmHdcTnrkA
# 371  Montgomery, Alabama      Caribbean  8GSuLA1nKMJRf_a0xKR80w
# 372  Montgomery, Alabama      Caribbean  B3L_WQk66myKWJcL1Y2pqg
# 373  Montgomery, Alabama      Caribbean  -YHd5XOit-gDNvelcGCGbw
# 374  Montgomery, Alabama      Caribbean  JSitNdyf694nJ8pC-CXrGw
#
#                                     name  \
# 0                        Urban Cookhouse
# 1                        Stockyard Grill
# 2            Plantation House and Garden
# 3                       Southern Comfort
# 4                    Common Bond Brewers
# ..                                   ...
# 370                Bates House of Turkey
# 371             Island Delight at Dexter
# 372  Island Delight Caribbean Restaurant
# 373                         D' Road Cafe
# 374                 LD CARIBBEAN CUISINE
#
#                                              image_url  \
# 0    https://s3-media1.fl.yelpcdn.com/bphoto/XY8xxa...
# 1    https://s3-media2.fl.yelpcdn.com/bphoto/gfK2DK...
# 2    https://s3-media3.fl.yelpcdn.com/bphoto/E4UqZ2...
# 3    https://s3-media2.fl.yelpcdn.com/bphoto/3WRpNu...
# 4    https://s3-media3.fl.yelpcdn.com/bphoto/xNl0HP...
# ..                                                 ...
# 370  https://s3-media1.fl.yelpcdn.com/bphoto/Tco-SS...
# 371  https://s3-media2.fl.yelpcdn.com/bphoto/NA0uwp...
# 372  https://s3-media4.fl.yelpcdn.com/bphoto/KPQQnc...
# 373  https://s3-media4.fl.yelpcdn.com/bphoto/M9wlHX...
# 374  https://s3-media2.fl.yelpcdn.com/bphoto/BYEwVG...
#
#                                                    url  closed  review_count  \
# 0    https://www.yelp.com/biz/urban-cookhouse-montg...   False           142
# 1    https://www.yelp.com/biz/stockyard-grill-montg...   False            51
# 2    https://www.yelp.com/biz/plantation-house-and-...   False            14
# 3    https://www.yelp.com/biz/southern-comfort-hope...   False           193
# 4    https://www.yelp.com/biz/common-bond-brewers-m...   False            16
# ..                                                 ...     ...           ...
# 370  https://www.yelp.com/biz/bates-house-of-turkey...   False            80
# 371  https://www.yelp.com/biz/island-delight-at-dex...   False            63
# 372  https://www.yelp.com/biz/island-delight-caribb...   False            41
# 373  https://www.yelp.com/biz/d-road-cafe-montgomer...   False           193
# 374  https://www.yelp.com/biz/ld-caribbean-cuisine-...   False             3
#
#      rating price        lat       long                 add1        city  \
# 0       4.5     $  32.360651 -86.157520  7712 Eastchase Pkwy  Montgomery
# 1       4.5     $  32.317361 -86.350667      4500 Mobile Hwy  Montgomery
# 2       4.0    $$  32.479502 -86.369687    3240 Grandview Rd   Millbrook
# 3       4.5    $$  32.269824 -86.363997        210 Wasden Rd   Hope Hull
# 4       5.0     $  32.377410 -86.313590          424 Bibb St  Montgomery
# ..      ...   ...        ...        ...                  ...         ...
# 370     3.5     $  31.851790 -86.642010    1001 Fort Dale Rd  Greenville
# 371     4.5    $$  32.377351 -86.308322        36 Dexter Ave  Montgomery
# 372     4.5     $  32.367615 -86.348618    323 Air Base Blvd  Montgomery
# 373     4.5    $$  32.376970 -86.309962    121 Montgomery St  Montgomery
# 374     4.5   NaN  32.622794 -85.449947      1460 Opelika Rd      AUBURN
#
#     state zip_code country         disp_ph price_attribute
# 0      AL    36117      US  (334) 239-7801    1.Affordable
# 1      AL    36108      US  (334) 288-2575    1.Affordable
# 2      AL    36054      US  (334) 285-1466      2.Moderate
# 3      AL    36043      US  (334) 280-0012      2.Moderate
# 4      AL    36104      US  (334) 676-2287    1.Affordable
# ..    ...      ...     ...             ...             ...
# 370    AL    36037      US  (334) 382-6123    1.Affordable
# 371    AL    36104      US  (334) 356-5641      2.Moderate
# 372    AL    36108      US  (334) 264-0041    1.Affordable
# 373    AL    36104      US  (334) 328-2938      2.Moderate
# 374    AL    36830      US  (334) 209-2216             NaN
#
# [375 rows x 19 columns]

# %%
variable4 = only_city['review_count']

plt.pie(variable4, labels=only_city, autopct="%1.1f%%", shadow=True, startangle= 0)
#centre_circle = plt.Circle((0,0),0.70,fc='white')
#fig = plt.gcf()
#fig.gca().add_artist(centre_circle)
plt.axis('equal') 
plt.tight_layout()
plt.show()

# %%
####intention: original pie chart. increase size so that the percentages are not overlapping snd explode slice:American 
####pie chart 2 working on making a dynamic pie chart to represent the % of cuisines by specific cities
####
