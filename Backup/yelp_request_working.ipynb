# %%
import csv
import pandas as pd
import requests
#import json as js
import matplotlib.pyplot as plt
from config import ykey
from collections import defaultdict

api_url = 'https://api.yelp.com'
search_path = '/v3/businesses/search'
business_path = '/v3/businesses/'
term = ['dinner']
location = ['San Francisco, CA', 'Oakland, CA']
limit = 50

headers = {'Authorization': 'Bearer ' + ykey}
params = {'term': term, 'location': location, 'limit': limit}

str(headers) + ' ' + str(params)
# Out:
# "{'Authorization': 'Bearer tNVSPxTZuK97fliYWToZrZpCGASCD0HlyF7s554dF_IdGdO1vAenbda05dWc6zUrsvXPE25NpvVJw1ZhohHYp-4n68rsIzrDPQAwh0lceNXGdjprDYMTAvHM_oMvXnYx'} {'term': ['dinner'], 'location': ['San Francisco, CA', 'Oakland, CA'], 'limit': 50}"

# %%
term
# Out:
# ['dinner']

# %%
url = api_url + search_path 
response = requests.get(url, headers=headers, params=params).json()

# %%
url = api_url + search_path 
headers = {'Authorization': 'Bearer ' + ykey}
cuisine_data = []
for city in location:
    for cuisine in term: 
        params = {'term': cuisine, 'location': city, 'limit': 50}
        response = requests.get(url, headers=headers, params=params).json()
        for r in range(5):
            if len(response["businesses"]) != 0:
                capture_dict = {
                        "search_city": city,
                        "search_cuisine": cuisine,
                }  
                if 'id' in response['businesses'][r].keys():
                    capture_dict["y_id"] = response['businesses'][r]['id']
                else: 
                    capture_dict["y_id"] = 'NA'
                if 'name' in response['businesses'][r].keys():
                    capture_dict["name"] = response['businesses'][r]['name']
                else: 
                    capture_dict["name"] = 'NA'
                if 'image_url' in response['businesses'][r].keys():
                    capture_dict["image_url"] = response['businesses'][r]['image_url']
                else: 
                    capture_dict["image_url"] = 'NA'
                if 'url' in response['businesses'][r].keys():
                    capture_dict["url"] = response['businesses'][r]['url']
                else: 
                    capture_dict["url"] = 'NA'
                if 'is_closed' in response['businesses'][r].keys():
                    capture_dict["closed"] = response['businesses'][r]['is_closed']
                else: 
                    capture_dict["closed"] = 'Unknown'
                if 'review_count' in response['businesses'][r].keys():
                    capture_dict["review_count"] = response['businesses'][r]['review_count']
                else: 
                    capture_dict["review_count"] = 0
                if 'rating' in response['businesses'][r].keys():
                    capture_dict["rating"] = response['businesses'][r]['rating']
                else: 
                    capture_dict["rating"] = ''
                if 'price' in response['businesses'][r].keys():
                    capture_dict["price"] = response['businesses'][r]['price']
                else: 
                    capture_dict["price"] = ''
                if 'latitude' in response['businesses'][r]['coordinates'].keys():
                    capture_dict["lat"] = response['businesses'][r]['coordinates']['latitude']
                else: 
                    capture_dict["lat"] = ''
                if 'longitute' in response['businesses'][r]['coordinates'].keys():
                    capture_dict["long"] = response['businesses'][r]['coordinates']['longitude']
                else: 
                    capture_dict["long"] = ''
                if 'address1' in response['businesses'][r]['location'].keys():
                    capture_dict["add1"] = response['businesses'][r]['location']['address1']
                else: 
                    capture_dict["add1"] = ''
                if 'city' in response['businesses'][r]['location'].keys():
                    capture_dict["city"] = response['businesses'][r]['location']['city']
                else: 
                    capture_dict["city"] = ''
                if 'state' in response['businesses'][r]['location'].keys():
                    capture_dict["state"] = response['businesses'][r]['location']['state']
                else: 
                    capture_dict["state"] = ''
                if 'zip_code' in response['businesses'][r]['location'].keys():
                    capture_dict["zip_code"] = response['businesses'][r]['location']['zip_code']
                else: 
                    capture_dict["zip_code"] = ''
                if 'country' in response['businesses'][r]['location'].keys():
                    capture_dict["country"] = response['businesses'][r]['location']['country']
                else: 
                    capture_dict["country"] = ''
                if 'display_phone' in response['businesses'][r].keys():
                    capture_dict["disp_ph"] = response['businesses'][r]['display_phone']
                else: 
                    capture_dict["disp_ph"] = ''
                    
                cuisine_data.append(capture_dict)

# %%
cuisine_data
df_data = pd.DataFrame(cuisine_data)

# %%
df_data
# Out:
#          search_city search_cuisine                    y_id  \
# 0  San Francisco, CA         dinner  lXMdrPSUmA9HfoHosOvzbQ
# 1  San Francisco, CA         dinner  2XwCg7dsjc_5zddwC4VaFA
# 2  San Francisco, CA         dinner  mdVq5YJoRhbQl2DD9BPQHw
# 3  San Francisco, CA         dinner  KkAVX3Wb7E3lP5F_f_8pXg
# 4  San Francisco, CA         dinner  ZoZjbOYR-apY8XvommlNUA
# 5        Oakland, CA         dinner  cQ00bfG7i-IKUlrJMVy86w
# 6        Oakland, CA         dinner  D_yAQ4tHlWp2CJSqFCeW_w
# 7        Oakland, CA         dinner  PGGtbjr8m4V54tWMgqYxmQ
# 8        Oakland, CA         dinner  L7I_bhmMacR1lcVUuWwuKg
# 9        Oakland, CA         dinner  vuJcJL8eJ_gomt865GnI_A
#
#                   name                                          image_url  \
# 0             Mamahuhu  https://s3-media2.fl.yelpcdn.com/bphoto/7W8x3y...
# 1                  Oji  https://s3-media2.fl.yelpcdn.com/bphoto/mphYvN...
# 2                 MaMo  https://s3-media1.fl.yelpcdn.com/bphoto/1HVt_h...
# 3  Liholiho Yacht Club  https://s3-media3.fl.yelpcdn.com/bphoto/FK2X98...
# 4            The House  https://s3-media2.fl.yelpcdn.com/bphoto/UzrNIk...
# 5        Kitchen Story  https://s3-media4.fl.yelpcdn.com/bphoto/7yXk35...
# 6         MAMA Oakland  https://s3-media2.fl.yelpcdn.com/bphoto/xUMZSc...
# 7               Marica  https://s3-media2.fl.yelpcdn.com/bphoto/gvEPu9...
# 8         Almond & Oak  https://s3-media2.fl.yelpcdn.com/bphoto/UaWnte...
# 9          Mockingbird  https://s3-media3.fl.yelpcdn.com/bphoto/_p7b6l...
#
#                                                  url  closed  review_count  \
# 0  https://www.yelp.com/biz/mamahuhu-san-francisc...   False            24
# 1  https://www.yelp.com/biz/oji-san-francisco?adj...   False            79
# 2  https://www.yelp.com/biz/mamo-san-francisco?ad...   False            94
# 3  https://www.yelp.com/biz/liholiho-yacht-club-s...   False          2377
# 4  https://www.yelp.com/biz/the-house-san-francis...   False          4812
# 5  https://www.yelp.com/biz/kitchen-story-oakland...   False            44
# 6  https://www.yelp.com/biz/mama-oakland-oakland?...   False            87
# 7  https://www.yelp.com/biz/marica-oakland-2?adju...   False          1977
# 8  https://www.yelp.com/biz/almond-and-oak-oaklan...   False            67
# 9  https://www.yelp.com/biz/mockingbird-oakland?a...   False           593
#
#    rating price        lat long              add1           city state  \
# 0     4.0        37.782670         517 Clement St  San Francisco    CA
# 1     4.0    $$  37.786171       1740 Buchanan St  San Francisco    CA
# 2     4.5    $$  37.803840       3659 Buchanan St  San Francisco    CA
# 3     4.5   $$$  37.788180          871 Sutter St  San Francisco    CA
# 4     4.5   $$$  37.798510         1230 Grant Ave  San Francisco    CA
# 5     4.5    $$  37.840730       5422 College Ave        Oakland    CA
# 6     4.0   $$$  37.809145          388 Grand Ave        Oakland    CA
# 7     4.5    $$  37.837980       5301 College Ave        Oakland    CA
# 8     4.0   $$$  37.812664         3311 Grand Ave        Oakland    CA
# 9     4.0    $$  37.803550            416 13th St        Oakland    CA
#
#   zip_code country         disp_ph
# 0    94118      US
# 1    94115      US  (415) 658-7103
# 2    94123      US  (415) 658-7150
# 3    94109      US  (415) 440-5446
# 4    94133      US  (415) 986-8612
# 5    94618      US  (510) 922-9443
# 6    94610      US  (510) 974-6372
# 7    94618      US  (510) 985-8388
# 8    94610      US  (510) 250-9550
# 9    94612      US  (510) 290-0331
