# %%
import csv
import pandas as pd
import requests
#import json as js
import matplotlib.pyplot as plt
from config import ykey
from collections import defaultdict

api_url = 'https://api.yelp.com'
search_path = '/v3/businesses/search'
business_path = '/v3/businesses/'
term = ['dinner']
location = ['San Francisco, CA', 'Oakland, CA']
limit = 50

headers = {'Authorization': 'Bearer ' + ykey}
params = {'term': term, 'location': location, 'limit': limit}

str(headers) + ' ' + str(params)
# Out:
# "{'Authorization': 'Bearer tNVSPxTZuK97fliYWToZrZpCGASCD0HlyF7s554dF_IdGdO1vAenbda05dWc6zUrsvXPE25NpvVJw1ZhohHYp-4n68rsIzrDPQAwh0lceNXGdjprDYMTAvHM_oMvXnYx'} {'term': ['dinner'], 'location': ['San Francisco, CA', 'Oakland, CA'], 'limit': 50}"

# %%
term
# Out:
# ['dinner']

# %%
url = api_url + search_path 
response = requests.get(url, headers=headers, params=params).json()

# %%
url = api_url + search_path 
headers = {'Authorization': 'Bearer ' + ykey}
cuisine_data = []
for city in location:
    for cuisine in term: 
        params = {'term': cuisine, 'location': city, 'limit': 10}
        response = requests.get(url, headers=headers, params=params).json()
        for r in range(len(response["businesses"])):
            if len(response["businesses"]) != 0:
                capture_dict = {
                        "search_city": city,
                        "search_cuisine": cuisine,
                }  
                if 'id' in response['businesses'][r].keys():
                    capture_dict["y_id"] = response['businesses'][r]['id']
                else: 
                    capture_dict["y_id"] = 'NA'
                if 'name' in response['businesses'][r].keys():
                    capture_dict["name"] = response['businesses'][r]['name']
                else: 
                    capture_dict["name"] = 'NA'
                if 'image_url' in response['businesses'][r].keys():
                    capture_dict["image_url"] = response['businesses'][r]['image_url']
                else: 
                    capture_dict["image_url"] = 'NA'
                if 'url' in response['businesses'][r].keys():
                    capture_dict["url"] = response['businesses'][r]['url']
                else: 
                    capture_dict["url"] = 'NA'
                if 'is_closed' in response['businesses'][r].keys():
                    capture_dict["closed"] = response['businesses'][r]['is_closed']
                else: 
                    capture_dict["closed"] = 'Unknown'
                if 'review_count' in response['businesses'][r].keys():
                    capture_dict["review_count"] = response['businesses'][r]['review_count']
                else: 
                    capture_dict["review_count"] = 0
                if 'rating' in response['businesses'][r].keys():
                    capture_dict["rating"] = response['businesses'][r]['rating']
                else: 
                    capture_dict["rating"] = ''
                if 'price' in response['businesses'][r].keys():
                    capture_dict["price"] = response['businesses'][r]['price']
                else: 
                    capture_dict["price"] = ''
                if 'latitude' in response['businesses'][r]['coordinates'].keys():
                    capture_dict["lat"] = response['businesses'][r]['coordinates']['latitude']
                else: 
                    capture_dict["lat"] = ''
                if 'longitute' in response['businesses'][r]['coordinates'].keys():
                    capture_dict["long"] = response['businesses'][r]['coordinates']['longitude']
                else: 
                    capture_dict["long"] = ''
                if 'address1' in response['businesses'][r]['location'].keys():
                    capture_dict["add1"] = response['businesses'][r]['location']['address1']
                else: 
                    capture_dict["add1"] = ''
                if 'city' in response['businesses'][r]['location'].keys():
                    capture_dict["city"] = response['businesses'][r]['location']['city']
                else: 
                    capture_dict["city"] = ''
                if 'state' in response['businesses'][r]['location'].keys():
                    capture_dict["state"] = response['businesses'][r]['location']['state']
                else: 
                    capture_dict["state"] = ''
                if 'zip_code' in response['businesses'][r]['location'].keys():
                    capture_dict["zip_code"] = response['businesses'][r]['location']['zip_code']
                else: 
                    capture_dict["zip_code"] = ''
                if 'country' in response['businesses'][r]['location'].keys():
                    capture_dict["country"] = response['businesses'][r]['location']['country']
                else: 
                    capture_dict["country"] = ''
                if 'display_phone' in response['businesses'][r].keys():
                    capture_dict["disp_ph"] = response['businesses'][r]['display_phone']
                else: 
                    capture_dict["disp_ph"] = ''
                    
                cuisine_data.append(capture_dict)

# %%
cuisine_data
df_data = pd.DataFrame(cuisine_data)

# %%
df_data
# Out:
#           search_city search_cuisine                    y_id  \
# 0   San Francisco, CA         dinner  lXMdrPSUmA9HfoHosOvzbQ
# 1   San Francisco, CA         dinner  mdVq5YJoRhbQl2DD9BPQHw
# 2   San Francisco, CA         dinner  KkAVX3Wb7E3lP5F_f_8pXg
# 3   San Francisco, CA         dinner  ZoZjbOYR-apY8XvommlNUA
# 4   San Francisco, CA         dinner  2XwCg7dsjc_5zddwC4VaFA
# 5   San Francisco, CA         dinner  4KfQnlcSu4bbTqnvGdGptw
# 6   San Francisco, CA         dinner  1hMD7RQogPDWpE-p3LKjXA
# 7   San Francisco, CA         dinner  ttarnopezxmp2ROB1N2PaA
# 8   San Francisco, CA         dinner  8kck3-K4zYKTJbJko0JlXQ
# 9   San Francisco, CA         dinner  u1SfgyXufKvyFLbYZGGI_g
# 10        Oakland, CA         dinner  cQ00bfG7i-IKUlrJMVy86w
# 11        Oakland, CA         dinner  D_yAQ4tHlWp2CJSqFCeW_w
# 12        Oakland, CA         dinner  PGGtbjr8m4V54tWMgqYxmQ
# 13        Oakland, CA         dinner  1aQn5XzAk_lVwxn997fphQ
# 14        Oakland, CA         dinner  bhnKl105GwMVVlsiUnwr2w
# 15        Oakland, CA         dinner  L7I_bhmMacR1lcVUuWwuKg
# 16        Oakland, CA         dinner  vuJcJL8eJ_gomt865GnI_A
# 17        Oakland, CA         dinner  VkZwT8AtDG9T-NOscVA79A
# 18        Oakland, CA         dinner  nNk28Wnm9kgPAfqOIFugPQ
# 19        Oakland, CA         dinner  UpXkkAMbb7LAMh2g7Xwddg
#
#                               name  \
# 0                         Mamahuhu
# 1                             MaMo
# 2              Liholiho Yacht Club
# 3                        The House
# 4                              Oji
# 5                          Beretta
# 6                             Loló
# 7                             Nopa
# 8   Farmhouse Kitchen Thai Cuisine
# 9              Che Fico Alimentari
# 10                   Kitchen Story
# 11                    MAMA Oakland
# 12                          Marica
# 13                             Mua
# 14                     Wood Tavern
# 15                    Almond & Oak
# 16                     Mockingbird
# 17                  Spinning Bones
# 18                            Mägo
# 19                       Hopscotch
#
#                                             image_url  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/7W8x3y...
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/1HVt_h...
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/FK2X98...
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/UzrNIk...
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/mphYvN...
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/RsCeyB...
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/-_hqew...
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/Li0xXD...
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/woO06s...
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/2N7lH_...
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/7yXk35...
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/xUMZSc...
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/gvEPu9...
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/b3jX1d...
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/Ouw9I3...
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/UaWnte...
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/_p7b6l...
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/u8pGwq...
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/ZjNhlm...
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/QLUTb0...
#
#                                                   url  closed  review_count  \
# 0   https://www.yelp.com/biz/mamahuhu-san-francisc...   False            24
# 1   https://www.yelp.com/biz/mamo-san-francisco?ad...   False            95
# 2   https://www.yelp.com/biz/liholiho-yacht-club-s...   False          2377
# 3   https://www.yelp.com/biz/the-house-san-francis...   False          4812
# 4   https://www.yelp.com/biz/oji-san-francisco?adj...   False            79
# 5   https://www.yelp.com/biz/beretta-san-francisco...   False          3605
# 6   https://www.yelp.com/biz/lol%C3%B3-san-francis...   False          2167
# 7   https://www.yelp.com/biz/nopa-san-francisco?ad...   False          5054
# 8   https://www.yelp.com/biz/farmhouse-kitchen-tha...   False          2360
# 9   https://www.yelp.com/biz/che-fico-alimentari-s...   False            44
# 10  https://www.yelp.com/biz/kitchen-story-oakland...   False            45
# 11  https://www.yelp.com/biz/mama-oakland-oakland?...   False            87
# 12  https://www.yelp.com/biz/marica-oakland-2?adju...   False          1977
# 13  https://www.yelp.com/biz/mua-oakland-2?adjust_...   False          3453
# 14  https://www.yelp.com/biz/wood-tavern-oakland?a...   False          1947
# 15  https://www.yelp.com/biz/almond-and-oak-oaklan...   False            67
# 16  https://www.yelp.com/biz/mockingbird-oakland?a...   False           593
# 17  https://www.yelp.com/biz/spinning-bones-alamed...   False            43
# 18  https://www.yelp.com/biz/m%C3%A4go-oakland?adj...   False            95
# 19  https://www.yelp.com/biz/hopscotch-oakland?adj...   False          1445
#
#     rating price        lat long                add1           city state  \
# 0      4.0        37.782670           517 Clement St  San Francisco    CA
# 1      4.5    $$  37.803840         3659 Buchanan St  San Francisco    CA
# 2      4.5   $$$  37.788180            871 Sutter St  San Francisco    CA
# 3      4.5   $$$  37.798510           1230 Grant Ave  San Francisco    CA
# 4      4.0    $$  37.786171         1740 Buchanan St  San Francisco    CA
# 5      4.0    $$  37.753829         1199 Valencia St  San Francisco    CA
# 6      4.0    $$  37.757346          974 Valencia St  San Francisco    CA
# 7      4.0   $$$  37.774830        560 Divisadero St  San Francisco    CA
# 8      4.0    $$  37.760261           710 Florida St  San Francisco    CA
# 9      4.5        37.777467        834 Divisadero St  San Francisco    CA
# 10     4.5    $$  37.840730         5422 College Ave        Oakland    CA
# 11     4.0   $$$  37.809145            388 Grand Ave        Oakland    CA
# 12     4.5    $$  37.837980         5301 College Ave        Oakland    CA
# 13     4.0    $$  37.814083          2442 Webster St        Oakland    CA
# 14     4.5   $$$  37.850677         6317 College Ave        Oakland    CA
# 15     4.0   $$$  37.812664           3311 Grand Ave        Oakland    CA
# 16     4.0    $$  37.803550              416 13th St        Oakland    CA
# 17     4.5    $$  37.761214             1205 Park St        Alameda    CA
# 18     4.5   $$$  37.823307        3762 Piedmont Ave        Oakland    CA
# 19     4.0    $$  37.809190       1915 San Pablo Ave        Oakland    CA
#
#    zip_code country         disp_ph
# 0     94118      US
# 1     94123      US  (415) 658-7150
# 2     94109      US  (415) 440-5446
# 3     94133      US  (415) 986-8612
# 4     94115      US  (415) 658-7103
# 5     94110      US  (415) 695-1199
# 6     94110      US  (415) 643-5656
# 7     94117      US  (415) 864-8643
# 8     94110      US  (415) 814-2920
# 9     94117      US  (415) 416-6980
# 10    94618      US  (510) 922-9443
# 11    94610      US  (510) 974-6372
# 12    94618      US  (510) 985-8388
# 13    94612      US  (510) 238-1100
# 14    94618      US  (510) 654-6607
# 15    94610      US  (510) 250-9550
# 16    94612      US  (510) 290-0331
# 17    94501      US  (510) 263-9290
# 18    94611      US  (510) 344-7214
# 19    94612      US  (510) 788-6217
